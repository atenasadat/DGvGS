# %% [markdown]
# <a href="https://colab.research.google.com/github/atenasadat/DGvGS/blob/main/DGvGS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pwd
# Out:
# /content

# %%
! ls
# Out:
# DGvGS  drive  sample_data

# %%
# Out:
# /content/drive/My Drive

# %%
! ls
# Out:
#  CGAN_.ipynb		  DGvGS.ipynb			   PytorchIntro.ipynb
# 'Copy of DGvGS.ipynb'	  gdrive			  'Sarcasm Detection'
# 'Copy of ML_Project_P2'   OfficeHomeDataset_10072016.zip   Untitled0.ipynb

# %%
! unzip 'OfficeHomeDataset_10072016.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00050.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00051.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00052.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00053.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00054.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00055.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00056.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00057.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00058.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00059.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00060.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00061.jpg
#   inflating: OfficeHomeDataset_10072016/Product/Speaker/00062.jpg
# ...

# %%
! ls
# Out:
#  CGAN_.ipynb		  gdrive			  'Sarcasm Detection'
# 'Copy of DGvGS.ipynb'	  OfficeHomeDataset_10072016	   Untitled0.ipynb
# 'Copy of ML_Project_P2'   OfficeHomeDataset_10072016.zip
#  DGvGS.ipynb		  PytorchIntro.ipynb

# %%
! git clone 'https://github.com/atenasadat/DGvGS.git'
# Out:
# Cloning into 'DGvGS'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 50 (delta 16), reused 31 (delta 7), pack-reused 0
# Unpacking objects: 100% (50/50), done.

# %%
cd /content/
# Out:
# /content

# %%
! ls
# Out:
# DGvGS  drive  sample_data

# %%
cd DGvGS/
# Out:
# /content/DGvGS

# %%
! git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# ## Preprocessing images

# %%
! bash run_pre.sh
# Out:
# Processing Art Ok
# Processing Clipart Ok
# Processing Product Ok
# Processing Real World Ok
# Processing Art Ok
# Processing Clipart Ok
# Processing Product Ok
# Processing Real World Ok

# %% [markdown]
# ## Run

# %%
! bash run_all.sh
# Out:
# Setup:
# 	batch_size: 128
# 	data_dir: data/pre
# 	dataset: OfficeHome
# 	iterations: 1000
# 	lr: 1e-05
# 	method: deep-all
# 	output_dir: result/train_all/OfficeHome/deep-all/run_0/A
# 	seed: 1832195010
# 	test_dom_idx: 0
# 	val_every: 20
# 	weight_decay: 5e-05
# Setting up model Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100% 233M/233M [00:04<00:00, 59.6MB/s]
# Ok
# Training
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 	iter     1/1000: train loss: 4.45735, train acc:   1.82% | val loss: 4.41448, val acc:   1.67%
# ...
